# %%
import os
from dotenv import load_dotenv
from web_scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
load_dotenv(override=True)
google_api_key=os.getenv("GEMINI_API_KEY")
gemini=OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
response=gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role":"user", "content":"what is 2+2"}])
print(response.choices[0].message.content)
# Out:
# python-dotenv could not parse statement starting at line 3
# 2 + 2 = 4

# %%
message="hello! this is my first message to you!!"
messages=[{"role": "user", "content":message}]
messages
# Out:
# [{'role': 'user', 'content': 'hello! this is my first message to you!!'}]

# %%
response=gemini.chat.completions.create(model="gemini-2.5-flash-lite",messages=messages)
print(response.choices[0].message.content)
# Out:
# Hello there! It's wonderful to hear from you, and welcome! I'm excited to be your first conversational partner.
#
# How can I help you today? Do you have any questions, a topic you'd like to discuss, or anything you'd like me to try? I'm ready for whatever you have in mind!

# %%
shivika=fetch_website_contents("https://shivika304.github.io/myPortfolio/")
print(shivika)
# Out:
# Shivika Singh | Software Engineer
#
# SS
# Initialising…
# SS
# About
# Skills
# Projects
# Certs
# Contact
# Hello, I'm
# Shivika Singh
# |
# View My Work
# Get In Touch
# About Me
# I'm an
# AI & Data Science undergraduate
# at GL Bajaj Institute of Technology and
#               Management (CGPA: 8.18/10), passionate about building meaningful software. My focus lies in backend
#               engineering, REST API development, and full-stack web applications.
# I enjoy solving algorithmic problems, designing clean system architectures, and turning complex
#               requirements into readable, maintainable code. When I'm not coding, I'm exploring new technologies or
#               sharpening my skills on LeetCode.
# GitHub
# LinkedIn
# LeetCode
# Resume
# 8.18
# CGPA / 10
# 3+
# Projects Built
# 6+
# Certifications
# B.Tech
# AI & Data
#                 Science
# Technical Skills
# Hover to pause · Drag to scrub
# Languages
# Java
# Python
# JavaScript
# C++
# SQL
# Frameworks & APIs
# Spring Boot
# Flask
# REST APIs
# HTML
# CSS
# Tools & Platforms
# Git
# GitHub
# Docker
# Postman
# Linux
# GitHub
#               Actions
# Core Concepts
# DSA
# OOP
# DBMS
# Computer Networks
# OS
# System
#               Design
# Projects
# Loan Default Risk Prediction
# ML model using Logistic Regression to classify loan applicants as high/low default risk, wrapped in a
#                 Flask REST API with full data preprocessing pipeline.
# Python
# Flask
# Scikit-learn
# Pandas
# YouTube Video Summarizer
# Flask application integrating LLM APIs to fetch YouTube transcripts and generate concise summaries. API endpoints tested via Postman with sub-2-second average response time.
# Python
# Flask
# LLM APIs
# Postman
# Full Stack Task Manager
# Full-stack web app with REST APIs supporting CRUD operations and user authentication. Spring Boot
#                 backend with MySQL, JavaScript frontend.
# Java
# Spring Boot
# MySQL
# JavaScript
# Certifications
# ☁️
# AWS Cloud Foundations
# Amazon Web Services
# 2026
# 🐍
# Python Essential 1
# Cisco Networking Academy
# 2026
# 🤖
# AI Skills Passport
# EY & Microsoft
# 2025
# ⚙️
# Java Full Stack Virtual Internship
# HackerRan

# %%
system_prompt=""""
You are an helpful assistant that analyzes the contents of the website,
and provides a short summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the response in code blocks. - respond just with markdown.
"""

user_prompt="""
Here are the contents of the website.
Provide a short summary of this website.
if it includes news or announcements, then summarize these too.
"""
